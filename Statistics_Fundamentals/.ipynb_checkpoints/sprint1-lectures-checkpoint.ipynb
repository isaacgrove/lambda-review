# %% [markdown]
# # Unit 1 Sprint 1

# %% [markdown]
# ### Resources
# - [JakeVDP 1.5 - Ipython, Shell Commands](https://jakevdp.github.io/PythonDataScienceHandbook/01.05-ipython-and-shell-commands.html)

# %%
# curl is a shell command that prints contents without loading
#
# !curl https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data

# %%
# Getting documentation
#
# ?pd.read_csv()
# help(pd.read_csv)

# %% [markdown]
# ## Day 1

# %%
import pandas as pd

# Load via URL - pass url as string to pd.read_csv()

flag_data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data'
# If you curl it, .data actually looks like a csv

df = pd.read_csv(flag_data_url)

df.head()


# Load from file (Colab)
#
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv('flag (1).data', names=column_headers)
# Out:
#       Afghanistan  5  1   648  16  10  2  0  3  5.1  ...  0.5  0.6  1.6  0.7  \
# 0         Albania  3  1    29   3   6  6  0  0    3  ...    0    0    1    0
# 1         Algeria  4  1  2388  20   8  2  2  0    3  ...    0    0    1    1
# 2  American-Samoa  6  3     0   0   1  1  0  0    5  ...    0    0    0    0
# 3         Andorra  3  1     0   0   6  0  3  0    3  ...    0    0    0    0
# 4          Angola  4  2  1247   7  10  5  0  2    3  ...    0    0    1    0
#
#    0.8  1.7  0.9 0.10  black  green.1
# 0    0    0    1    0    red      red
# 1    0    0    0    0  green    white
# 2    1    1    1    0   blue      red
# 3    0    0    0    0   blue      red
# 4    0    1    0    0    red    black
#
# [5 rows x 30 columns]

# %%
# Sometimes you have to fix headers yourself
column_headers = ['name', 'landmass', 'zone', 'area', 'population', 'language', 
                  'religion', 'bars', 'stripes', 'colours', 'red', 'green', 
                  'blue', 'gold', 'white', 'black', 'orange', 'mainhue', 
                  'circles', 'crosses', 'saltires', 'quarters', 'sunstars', 
                  'crescent', 'triangle', 'icon', 'animate', 'text', 'topleft', 
                  'botright']
df = pd.read_csv(flag_data_url, names=column_headers)
df.head()


# Or you can make a header row with no names
#
# df = pd.read_csv(flag_data_url, header=None)
# Out:
#              name  landmass  zone  area  population  language  religion  bars  \
# 0     Afghanistan         5     1   648          16        10         2     0
# 1         Albania         3     1    29           3         6         6     0
# 2         Algeria         4     1  2388          20         8         2     2
# 3  American-Samoa         6     3     0           0         1         1     0
# 4         Andorra         3     1     0           0         6         0     3
#
#    stripes  colours  ...  saltires  quarters  sunstars  crescent  triangle  \
# 0        3        5  ...         0         0         1         0         0
# 1        0        3  ...         0         0         1         0         0
# 2        0        3  ...         0         0         1         1         0
# 3        0        5  ...         0         0         0         0         1
# 4        0        3  ...         0         0         0         0         0
#
#    icon  animate text  topleft  botright
# ...

# %% [markdown]
# ### Basic Pandas
#
# - df.shape
# - df.head()
# - df.tail()
# - df.describe()
# - df.dtypes
# - df['column'].value_counts()
# - df.isnull().sum()
# - df.fillna()
# - df.dropna()
# - df.drop()
# - pd.crosstab()

# %%
# Read in another dataset, look at descriptive statistics, check for nulls, make some plots

column_headers = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 
                 'marital-status', 'occupation', 'relationship', 'race', 'sex', 
                 'capital-gain', 'capital-loss', 'hours-per-week', 
                 'native-country', 'income']

adult_data = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
df = pd.read_csv(adult_data, names=column_headers)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.describe()


# df.describe(exclude='number')
# df.describe(include='all')
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# Upon further inspection, null values are encoded as " ?"

import numpy as np
df = df.replace({" ?": np.NaN})

df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
df['native-country'][14]
# Out:
# nan

# %%
# Visualizations

df['education-num'].value_counts().sort_index().plot();

# %%
# More viz types
#
# df['age'].hist(bins=72);
# df.plot.scatter('age', 'hours-per-week');
# df['age'].plot.kde();
df['age'].plot.density();

# %%
# Crosstab for categorical variables

pd.crosstab(df['education'], df['sex'])

# Or save to variable
#
# table = pd.crosstab(df['education'], df['sex'])
# table


# These can be plotted too
#
# table.plot();
# table.plot.bar();
# table.plot(kind='bar', stacked='true');
# pd.crosstab(df['education'], df['sex']).plot(kind='bar', stacked='true');
# Out:
# sex             Female   Male
# education
#  10th              295    638
#  11th              432    743
#  12th              144    289
#  1st-4th            46    122
#  5th-6th            84    249
#  7th-8th           160    486
#  9th               144    370
#  Assoc-acdm        421    646
#  Assoc-voc         500    882
#  Bachelors        1619   3736
#  Doctorate          86    327
#  HS-grad          3390   7111
#  Masters           536   1187
#  Preschool          16     35
#  Prof-school        92    484
#  Some-college     2806   4485

# %% [markdown]
# ## Day 2
